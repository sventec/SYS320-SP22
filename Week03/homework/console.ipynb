# %% [markdown]
# # URLHAUS

# %%
import urlHaus as u
import importlib
importlib.reload(u)
# Out:
# <module 'urlHaus' from 'd:\\school-files\\SYS320-SP22\\Week03\\homework\\urlHaus.py'>

# %%
u.url_haus_open('../../logs/urlHaus.csv', '.*\.edu.*|.*\.gov.*')
# Out:
#                 URL: hxxps://grabovoi.education/wp-includes/QONu3Rk/
#                 Info: https://urlhaus.abuse.ch/url/2009385/
#                 ************************************************************
#
#                 URL: hxxp://mitt.edu.in/cuban.php
#                 Info: https://urlhaus.abuse.ch/url/2008172/
#                 ************************************************************
#
#                 URL: hxxp://mitt.edu.in/splotched.php
#                 Info: https://urlhaus.abuse.ch/url/2008159/
#                 ************************************************************
#
#                 URL: hxxps://forms.saurashtrauniversity.edu/belt.php
#                 Info: https://urlhaus.abuse.ch/url/2008131/
#                 ************************************************************
#
#                 URL: hxxp://mitt.edu.in/swearword.php
#                 Info: https://urlhaus.abuse.ch/url/2008118/
# ...

# %%
u.url_haus_open('../../logs/urlHaus.csv', '.*\.win32.*')
# Out:
#                 URL: hxxp://103.171.0.134/Registry/.win32.exe
#                 Info: https://urlhaus.abuse.ch/url/2017874/
#                 ************************************************************
#
#                 URL: hxxp://198.46.132.195/Registry/.win32.exe
#                 Info: https://urlhaus.abuse.ch/url/2017585/
#                 ************************************************************
#
#                 URL: hxxp://103.89.90.10/Registry/.win32.exe
#                 Info: https://urlhaus.abuse.ch/url/2017583/
#                 ************************************************************
#
#                 URL: hxxp://103.171.0.134/googleCRC/.win32.exe
#                 Info: https://urlhaus.abuse.ch/url/2011286/
#                 ************************************************************
#
#                 URL: hxxp://198.46.132.195/googleCRC/.win32.exe
#                 Info: https://urlhaus.abuse.ch/url/2011284/
# ...
